# %%
import utils
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# 110000	风景名胜	风景名胜相关	旅游景点
# 110200	风景名胜	风景名胜	风景名胜
# 110201	风景名胜	风景名胜	世界遗产
# 110202	风景名胜	风景名胜	国家级景点
# 110203	风景名胜	风景名胜	省级景点
# 110208	风景名胜	风景名胜	海滩

# 上海市	310000	021
# 上海市市辖区	310100	021
# 黄浦区	310101	021
# 徐汇区	310104	021
# 长宁区	310105	021
# 静安区	310106	021
# 普陀区	310107	021
# 虹口区	310109	021
# 杨浦区	310110	021
# 闵行区	310112	021
# 宝山区	310113	021
# 嘉定区	310114	021
# 浦东新区	310115	021
# 金山区	310116	021
# 松江区	310117	021
# 青浦区	310118	021
# 奉贤区	310120	021
# 崇明区	310151	021

POI = utils.getPOI(poi_code=110202, ad_code=310000)
# Out:
# Rows: 32

# %%
POI.head()
# Out:
#        poi_id parent        name              typ  typ1  typ2   typ3 business_type       address         lon        lat                              tel postcode          website   pcode pname  citycode cityname  adcode adname         entr_location exit_location   alias  parking_type tag business_area  rating   cost
# 0  B0FFF0FMKE     []   崇明岛国家地质公园  风景名胜;风景名胜;国家级景点  风景名胜  风景名胜  国家级景点          tour           堡湖路  121.231400  31.726844                               []       []               []  310000   上海市        21      上海市  310151    崇明区  121.239408,31.727616            []      []           NaN  []            []     4.5     []
# 1  B00156EKMZ     []         闻道园  风景名胜;风景名胜;国家级景点  风景名胜  风景名胜  国家级景点          tour      潘泾路2888号  121.353067  31.437086        021-66866777;021-66865538       []               []  310000   上海市        21      上海市  310113    宝山区  121.357916,31.438746            []      []           NaN  []            []     4.3  80.00
# 2  B00156EG8P     []      光明瑞华果园  风景名胜;风景名胜;国家级景点  风景名胜  风景名胜  国家级景点          tour  新海镇北沿公路3176号  121.329310  31.814364                     021-59658558       []               []  310000   上海市        21      上海市  310151    崇明区  121.331196,31.811699            []      []           NaN  []            []     4.3  50.00
# 3  B00156E3VY     []        顾村公园  风景名胜;风景名胜;国家级景点  风景名胜  风景名胜  国家级景点          tour      沪太路4788号  121.368712  31.339645        021-36621019;021-56045199       []               []  310000   上海市        21      上海市  310113    宝山区  121.382364,31.346475            []      []           NaN  []            顾村     4.6  20.00
# 4  B00155LYLB     []  上海海湾国家森林公园  风景名胜;风景名胜;国家级景点  风景名胜  风景名胜  国家级景点          tour     随塘河路1677号  121.690615  30.861390  021-57169090;021-57169696;12301       []  www.shfpark.com  310000   上海市        21      上海市  310120    奉贤区   121.677894,30.86661            []  海湾森林公园           NaN  []            []     4.4  80.00
